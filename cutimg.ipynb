# %%
import cv2
from matplotlib import pyplot as plt


image = cv2.imread('/mnt/d/examgrading/BuilModelDetecSBD_DT/Dataset/arena/mdt/MDT.c2_quanghung.0006.jpg')

ds = []
for i in range(0,208,23):
    for j in range(0,17,16):
        imgcrop=image[i:i+23,j:j+32]
        ds.append(imgcrop)
print(len(ds))
for image in ds:
    plt.imshow(image)
    plt.show()
# Out:
# 20
